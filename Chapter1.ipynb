# %% [markdown]
# ## Chapter 1. Language Processing and Python.

# %% [markdown]
# #### Solved Exercises.

# %% [markdown]
# #### 1. Try using the Python interpreter as a calculator, and typing expressions like 12 / (4 + 1).

# %%
12 / (4 + 1)
# Out:
# 2.4

# %% [markdown]
# #### 2. Given an alphabet of 26 letters, there are 26 to the power 10, or 26 ** 10, 10- letter strings we can form. That works out to 141167095653376L (the L at the end just indicates that this is Python’s long-number format). How many hundred-letter strings are possible?

# %%
26**100
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %% [markdown]
# #### 3. The Python multiplication operation can be applied to lists. What happens when you type ['Monty', 'Python'] * 20, or 3 * sent1?

# %%
['Monty', 'Python']*20
# Out:
# ['Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python',
#  'Monty',
#  'Python']

# %% [markdown]
# #### 4. Review Section 1.1 on computing with language. How many words are there in text2? How many distinct words are there?

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
print("Words in Text2 are {}".format(len(text2)))
print("Distinct Words in Text2 are {}".format(len(set(text2))))
# Out:
# Words in Text2 are 141576
# Distinct Words in Text2 are 6833

# %% [markdown]
# #### 5. Compare the lexical diversity scores for humor and romance fiction in Table 1-1. Which genre is more lexically diverse?

# %% [markdown]
# Romance has a lexical diversity of 8.3 while humor has a diversity of 4.3, hence Romance is more lexically diverse.

# %% [markdown]
# #### 6. Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
text2.dispersion_plot(['Elinor', 'Marianne', 'Edward', 'Willoughby'])

# %% [markdown]
# #### 7. Find the collocations in text5.

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# #### 8. Consider the following Python expression: len(set(text4)). State the purpose of this expression. Describe the two steps involved in performing this computation.

# %% [markdown]
# Set function is going to output list of distinct tokens , while len function counts the number of objects in that list.

# %% [markdown]
# #### 9. a. Define a string and assign it to a variable, e.g., my_string = 'My String' (but put something more interesting in the string). Print the contents of this variable in two ways, first by simply typing the variable name and pressing Enter, then by using the print statement.

# %%
varString = "This is a test string."
varString
# Out:
# 'This is a test string.'

# %%
print(varString)
# Out:
# This is a test string.

# %% [markdown]
# #### 9. b. Try adding the string to itself using my_string + my_string, or multiplying it by a number, e.g., my_string * 3. Notice that the strings are joined together without any spaces. How could you fix this?

# %%
varString = varString*2

# %%
print(varString)
# Out:
# This is a test string.This is a test string.

# %% [markdown]
# This can be fixed by adding an extra space at the end of actual string.

# %% [markdown]
# #### 10. Define a variable my_sent to be a list of words, using the syntax my_sent = ["My", "sent"] (but with your own words, or a favorite saying).
#
# #### a. Use ' '.join(my_sent) to convert this into a string.

# %%
my_sent = ['This', 'should', 'suffice']
my_sent = ' '.join(my_sent)
print(my_sent)
# Out:
# This should suffice

# %% [markdown]
# #### 10. b. Use split() to split the string back into the list form you had to start with.

# %%
my_sent = my_sent.split()
print(my_sent)
# Out:
# ['This', 'should', 'suffice']

# %% [markdown]
# #### 11. Define several variables containing lists of words, e.g., phrase1, phrase2, and so on. Join them together in various combinations (using the plus operator) to form whole sentences. What is the relationship between len(phrase1 + phrase2) and len(phrase1) + len(phrase2)?

# %%
phrase1 = ['This', 'should', 'be', 'phrase', '1']
phrase2 = ['This', 'should', 'be', 'phrase', '2']
phrase_add = phrase1 + phrase2
print("The length of added Phrase is {}".format(len(phrase_add)))
print("While the individual addition of the phrase length is {}".format(str(len(phrase1) + len(phrase2))))
# Out:
# The length of added Phrase is 10
# While the individual addition of the phrase length is 10

# %% [markdown]
# The sum of both the phrase is equal.

# %% [markdown]
# #### 12. Consider the following two expressions, which have the same value. Which one will typically be more relevant in NLP? Why?
#
# #### a. "Monty Python"[6:12]
#
# #### b. ["Monty", "Python"][1]

# %% [markdown]
# Second would be more relevant in NLP, as we won't always be knowing the length of the string, and neither would any specifics. Hence to query objects indexing a list is always a better idea.

# %% [markdown]
# #### 13. We have seen how to represent a sentence as a list of words, where each word is a sequence of characters. What does sent1[2][2] do? Why? Experiment with other index values.

# %% [markdown]
# sent1[2][2] takes the third word from thr sentence and prints the third character from that word.

# %% [markdown]
# #### 14. The first sentence of text3 is provided to you in the variable sent3. The index of the in sent3 is 1, because sent3[1] gives us 'the'. What are the indexes of the two other occurrences of this word in sent3?

# %%
count = 0
for word in sent3:
    if word == 'the':
        print(count)
    count += 1
# Out:
# 1
# 5
# 8

# %% [markdown]
# #### 15. Review the discussion of conditionals in Section 1.4. Find all words in the Chat Corpus (text5) starting with the letter b. Show them in alphabetical order.

# %%
container = []
for word in text5:
    try:
        if word[0] == 'b':
            container.append(word)
    except IndexError:
        pass
print(sorted(set(container)))
# Out:
# ['b', 'b-day', 'b/c', 'b4', 'babay', 'babble', 'babblein', 'babe', 'babes', 'babi', 'babies', 'babiess', 'baby', 'babycakeses', 'bachelorette', 'back', 'backatchya', 'backfrontsidewaysandallaroundtheworld', 'backroom', 'backup', 'bacl', 'bad', 'bag', 'bagel', 'bagels', 'bahahahaa', 'bak', 'baked', 'balad', 'balance', 'balck', 'ball', 'ballin', 'balls', 'ban', 'band', 'bandito', 'bandsaw', 'banjoes', 'banned', 'baord', 'bar', 'barbie', 'bare', 'barely', 'bares', 'barfights', 'barks', 'barn', 'barrel', 'base', 'bases', 'basically', 'basket', 'battery', 'bay', 'bbbbbyyyyyyyeeeeeeeee', 'bbiam', 'bbl', 'bbs', 'bc', 'be', 'beach', 'beachhhh', 'beam', 'beams', 'beanbag', 'beans', 'bear', 'bears', 'beat', 'beaten', 'beatles', 'beats', 'beattles', 'beautiful', 'because', 'beckley', 'become', 'bed', 'bedford', 'bedroom', 'beeeeehave', 'beeehave', 'been', 'beer', 'before', 'beg', 'begin', 'behave', 'behind', 'bein', 'being', 'beleive', 'believe', 'belive', 'bell', 'belly', 'belong', 'belongings
# ...

# %% [markdown]
# #### 16. Type the expression range(10) at the interpreter prompt. Now try range(10, 20),range(10, 20, 2),andrange(20, 10, -2).We will see a variety of uses for this built-in function in later chapters.

# %%
print(range(10))
# Out:
# range(0, 10)

# %%
range(10,20)
# Out:
# range(10, 20)

# %%
range(10,20,2)
# Out:
# range(10, 20, 2)

# %%
range(20,10,-2)
# Out:
# range(20, 10, -2)

# %% [markdown]
# #### 17. Use text9.index() to find the index of the word sunset. You’ll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
text9.index('sunset')
# Out:
# 629

# %%
' '.join(text9[615:633])
# Out:
# 'THE TWO POETS OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London'

# %% [markdown]
# #### 18. Using list addition, and the set and sorted operations, compute the vocabulary of the sentences sent1 ... sent8.

# %%
final_sent = sent1 + sent2 + sent3 + sent4 + sent5 + sent6 + sent7 +sent8

# %%
print(sorted(set(final_sent)))
# Out:
# ['!', ',', '-', '.', '1', '25', '29', '61', ':', 'ARTHUR', 'Call', 'Citizens', 'Dashwood', 'Fellow', 'God', 'House', 'I', 'In', 'Ishmael', 'JOIN', 'KING', 'MALE', 'Nov.', 'PMing', 'Pierre', 'Representatives', 'SCENE', 'SEXY', 'Senate', 'Sussex', 'The', 'Vinken', 'Whoa', '[', ']', 'a', 'and', 'as', 'attrac', 'been', 'beginning', 'board', 'clop', 'created', 'director', 'discreet', 'earth', 'encounters', 'family', 'for', 'had', 'have', 'heaven', 'in', 'join', 'lady', 'lol', 'long', 'me', 'nonexecutive', 'of', 'old', 'older', 'people', 'problem', 'seeks', 'settled', 'single', 'the', 'there', 'to', 'will', 'wind', 'with', 'years']

# %% [markdown]
# #### 19. What is the difference between the following two lines? Which one will give a larger value? Will this be the case for other texts?
#
# > sorted(set([w.lower() for w in text1]))
#
# > sorted([w.lower() for w in set(text1)])

# %% [markdown]
# Second should give a larger result set with respect to the first one, due to the fact that words in list are case sensitive, hence same words with different case would be different words to the system.

# %%
len(sorted(set([w.lower() for w in text1])))
# Out:
# 17231

# %%
len(sorted([w.lower() for w in set(text1)]))
# Out:
# 19317

# %% [markdown]
# #### 20. What is the difference between the following two tests: w.isupper() and not w.islower()?

# %% [markdown]
# There is no difference. Both will display the same result as they are same logical expression.

# %% [markdown]
# #### 21. Write the slice expression that extracts the last two words of text2.

# %%
text2[-2:]
# Out:
# ['THE', 'END']

# %% [markdown]
# #### 22. Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %%
fdist = FreqDist(text5)
for sample in fdist:
    print(sample, fdist[sample])
# Out:
# . 1268
# JOIN 1021
# PART 1016
# ? 737
# lol 704
# to 658
# i 648
# the 646
# you 635
# , 596
# I 576
# a 568
# hi 546
# me 415
# ... 412
# is 372
# .. 361
# in 357
# ACTION 346
# ! 342
# and 335
# it 332
# that 274
# hey 264
# my 242
# of 202
# u 200
# 's 195
# for 188
# on 186
# what 183
# here 181
# are 178
# not 170
# .... 170
# do 168
# all 165
# have 164
# up 160
# like 156
# no 155
# with 152
# chat 142
# was 142
# n't 141
# so 139
# your 137
# / 133
# 'm 133
# good 130
# im 128
# how 128
# too 125
# just 125
# any 123
# there 120
# U7 119
# U34 119
# pm 108
# wanna 107
# out 107
# lmao 107
# be 107
# can 105
# Hi 104
# know 103
# get 102
# :) 101
# U35 101
# ya 100
# who 99
# room 98
# if 98
# at 98
# : 96
# ok 96
# am 93
# - 93
# from 92
# did 92
# U18 92
# wb 91
# but 90
# or 88
# one 87
# " 87
# LOL 87
# this 86
# he 84
# well 81
# m 81
# U30 81
# now 79
# oh 79
# U19 79
# back 78
# hiya 78
# they 77
# U52 77
# dont 75
# @ 75
# yeah 75
# see 75
# go 73
# ..... 73
# U54 73
# ...

# %% [markdown]
# #### 23. Review the discussion of looping with conditions in Section 1.4. Use a combination of for and if statements to loop over the words of the movie script for Monty Python and the Holy Grail (text6) and print all the uppercase words, one per line.

# %%
for word in text6:
    try:
        if word.isupper():
            print(word)
    except:
        pass
# Out:
# SCENE
# KING
# ARTHUR
# SOLDIER
# ARTHUR
# I
# SOLDIER
# ARTHUR
# I
# I
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# A
# ARTHUR
# SOLDIER
# ARTHUR
# SOLDIER
# I
# ARTHUR
# I
# SOLDIER
# SOLDIER
# SOLDIER
# I
# ARTHUR
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SOLDIER
# SCENE
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CART
# MASTER
# CUSTOMER
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# DEAD
# PERSON
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# DEAD
# PERSON
# I
# I
# CUSTOMER
# CART
# MASTER
# CUSTOMER
# CART
# MASTER
# I
# CUSTOMER
# CART
# MASTER
# SCENE
# ARTHUR
# DENNIS
# ...

# %% [markdown]
# #### 24. Write expressions for finding all words in text6 that meet the following conditions.The result should be in the form of a list of words: ['word1', 'word2', ...].
#
# #### a. Ending in ize

# %%
container = []
for word in text6:
    try:
        if word[-3:] == 'ize':
            container.append(word)
    except:
        pass
len(container)
# Out:
# 0

# %% [markdown]
# #### b. Containing the letter z

# %%
container = []
for word in text6:
    try:
        if 'z' in word.lower():
            container.append(word)
    except:
        pass

print(container)
# Out:
# ['zone', 'amazes', 'Fetchez', 'Fetchez', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'Zoot', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'AMAZING', 'zoop', 'zoo', 'zhiv', 'frozen', 'zoosh']

# %% [markdown]
# #### c. Containing the sequence of letters pt

# %%
container = []
for word in text6:
    try:
        if 'pt' in word.lower():
            container.append(word)
    except:
        pass

print(container)
# Out:
# ['empty', 'aptly', 'Thpppppt', 'Thppt', 'Thppt', 'empty', 'Thppppt', 'temptress', 'temptation', 'ptoo', 'Chapter', 'excepting', 'Thpppt']

# %% [markdown]
# #### d. All lowercase letters except for an initial capital (i.e., titlecase)

# %%
container = []
for word in text6:
    try:
        if word[-1].islower():
            if word.islower():
                container.append(word)
    except:
        pass

print(container)
# Out:
# ['wind', 'clop', 'clop', 'clop', 'there', 'clop', 'clop', 'clop', 'goes', 'there', 'is', 'son', 'of', 'from', 'the', 'castle', 'of', 'of', 'the', 'defeator', 'of', 'the', 'sovereign', 'of', 'all', 'the', 'other', 'one', 'am', 'and', 'this', 'is', 'my', 'trusty', 'servant', 'have', 'ridden', 'the', 'length', 'and', 'breadth', 'of', 'the', 'land', 'in', 'search', 'of', 'knights', 'who', 'will', 'join', 'me', 'in', 'my', 'court', 'at', 'must', 'speak', 'with', 'your', 'lord', 'and', 'master', 'on', 'a', 'horse', 're', 'using', 'coconuts', 've', 'got', 'two', 'empty', 'halves', 'of', 'coconut', 'and', 'you', 're', 'bangin', 'em', 'together', 'have', 'ridden', 'since', 'the', 'snows', 'of', 'winter', 'covered', 'this', 'land', 'through', 'the', 'kingdom', 'of', 'through', 'd', 'you', 'get', 'the', 'coconuts', 'found', 'them', 'them', 'coconut', 's', 'tropical', 'do', 'you', 'mean', 'this', 'is', 'a', 'temperate', 'zone', 'swallow', 'may', 'fly', 'south', 'with', 'the', 'sun', 'or', 'the',
# ...

# %% [markdown]
# #### 25. Define sent to be the list of words ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']. Now write code to perform the following tasks:
#
# #### a. Print all words beginning with sh.

# %%
sent = ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']
for word in sent:
    if word.startswith('sh'):
        print(word)
# Out:
# she
# shells
# shore

# %% [markdown]
# #### b. Print all words longer than four characters

# %%
print([w for w in sent if len(w)>4])
# Out:
# ['sells', 'shells', 'shore']

# %% [markdown]
# #### 26. What does the following Python code do? sum([len(w) for w in text1])
#
# #### Can you use it to work out the average word length of a text?

# %% [markdown]
# The code calculates the sum of length of words in text1.
# Yes this can be used to work out the average word length of a text.

# %% [markdown]
# #### 27. Define a function called vocab_size(text) that has a single parameter for the text, and which returns the vocabulary size of the text.

# %%
def vocab_size(text):
    return len(set(text))

# %% [markdown]
# #### 28. Define a function percent(word, text) that calculates how often a given word occurs in a text and expresses the result as a percentage.

# %%
def percent(word, text):
    count = 0
    for x in text:
        if x == word:
            count += 1
    return 100*count/len(text)

# %% [markdown]
# #### 29. We have been using sets to store vocabularies. Try the following Python expression: set(sent3) < set(text1). Experiment with this using different arguments to set(). What does it do? Can you think of a practical application for this?

# %% [markdown]
# Set is a mathematical object that contains distinct objects in it and is non-mutable. It can perform all the set operation that are possible on a mathematical set model.
#
# A practical application can be removal of duplicates, number of different words from two given texts(comparisons), etc.
